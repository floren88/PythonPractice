# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
randomNumber = np.random.rand(10)

# %%
print(randomNumber)
# Out:
# [0.31622747 0.18789577 0.10349275 0.30466898 0.02300117 0.51399271
#  0.1751089  0.83149977 0.75990282 0.35992564]

# %%
#select the style of the plot
style.use('ggplot')
#plot the random number
plt.plot(randomNumber,'g',label='line one',linewidth=2)
#x-axis is num of random numbers(index)
plt.xlabel('Range')
#y-axis is actual random number
plt.ylabel('Numbers')
#Title of the plot
plt.title('First Plot')
# Out:
# Text(0.5, 1.0, 'First Plot')

# %% [markdown]
# # Demo
# ![image.png](attachment:image.png)

# %%
cause='Chronic Diseases','Unintentional Injuries','Alzheimers','Influenza and Pneumonia','Sepsis','Others'
percentil = [62,5,4,2,1,26]
sum(percentil)
# Out:
# 100

# %%
plt.figure(figsize=(10,10))
explode = (0.05,0,0,0,0,0)
plt.pie(percentil,labels=cause,explode=explode,autopct='%1.1f%%',startangle=70)
plt.axis('equal')
plt.title('Ohio State - 2012 : Leading Causes of Death')
# Out:
# Text(0.5, 1.0, 'Ohio State - 2012 : Leading Causes of Death')
